# %%
from langchain_core.messages import HumanMessage
from langchain_ollama import ChatOllama

# %%
model = ChatOllama(
    model="Llama-3.1-Swallow-8B:latest",
    base_url="http://localhost:11434",  # 省略可
    temperature=0.2,
)

response = model.invoke(
    [HumanMessage(content="LangChainとOllamaの接続テスト")]
)

# %%
response.content
# Out:
# 'OllamaでLangChainを使用するための基本的な接続テストは以下の通りです。\n\n1.  **Ollamaのインストール:** Ollamaがインストールされていることを確認してください。\n2.  **LLMの選択:** 使用したいLLM（例：GPT-3.5-turbo）をOllamaで指定します。`ollama run <model_name>` で実行できます。\n3.  **LangChainのインストール:** `pip install langchain`\n4.  **接続テストスクリプト:**\n\n```python'
